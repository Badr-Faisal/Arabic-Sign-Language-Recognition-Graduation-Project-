# %%
import time
import os
import cv2
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import arabic_reshaper
from PIL import ImageFont, ImageDraw, Image
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Path to your dataset
dataset_path = 'RGB ArSL dataset'  # Main folder with subfolders for each letter

# %%
def load_dataset(folder):
    """Load dataset from the folder containing subfolders of images for each letter."""
    images = []
    labels = []

    # Iterate over each subfolder (corresponding to a letter/gesture)
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if os.path.isdir(label_folder):
            for img_file in os.listdir(label_folder):
                img_path = os.path.join(label_folder, img_file)
                img = cv2.imread(img_path)
                if img is not None:  # Ensure the image was read correctly
                    img = cv2.resize(img, (64, 64))
                    images.append(img)
                    labels.append(label)

    return np.array(images), np.array(labels)

# %%
# Load the dataset
X, y = load_dataset(dataset_path)

# %%
#Converts labels (letters) into numerical values.
# Encode labels and create a dynamic label map
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_categorical = to_categorical(y_encoded) #Converts numerical labels into one-hot encoded vectors

# %%
# Save the label classes
np.save('label_classes.npy', label_encoder.classes_)  # Save classes for later use

# %%
# Create a dynamic label map based on the encoder's order
label_map = {i: label for i, label in enumerate(label_encoder.classes_)}
print(f"Label Map: {label_map}")  # Ensure it matches your expectations
# Out:
# Label Map: {0: 'Ain', 1: 'Al', 2: 'Alef', 3: 'Beh', 4: 'Dad', 5: 'Dal', 6: 'Feh', 7: 'Ghain', 8: 'Hah', 9: 'Heh', 10: 'Jeem', 11: 'Kaf', 12: 'Khah', 13: 'Laa', 14: 'Lam', 15: 'Meem', 16: 'Noon', 17: 'Qaf', 18: 'Reh', 19: 'Sad', 20: 'Seen', 21: 'Sheen', 22: 'Tah', 23: 'Teh', 24: 'Teh_Marbuta', 25: 'Thal', 26: 'Theh', 27: 'Waw', 28: 'Yeh', 29: 'Zah', 30: 'Zain', 31: 'masafa', 32: 'mash'}

# %%
# Define the mapping from English labels to Arabic letters
english_to_arabic = {
    'Ain': 'ع', 'Al': 'ال', 'Alef': 'ا', 'Beh': 'ب', 'Dad': 'ض', 'Dal': 'د',
    'Feh': 'ف', 'Ghain': 'غ', 'Hah': 'ح', 'Heh': 'ه', 'Jeem': 'ج', 'Kaf': 'ك',
    'Khah': 'خ', 'Laa': 'لا', 'Lam': 'ل', 'Meem': 'م', 'Noon': 'ن', 'Qaf': 'ق',
    'Reh': 'ر', 'Sad': 'ص', 'Seen': 'س', 'Sheen': 'ش', 'Tah': 'ط', 'Teh': 'ت',
    'Teh_Marbuta': 'ة', 'Thal': 'ذ', 'Theh': 'ث', 'Waw': 'و', 'Yeh': 'ي',
    'Zah': 'ظ', 'Zain': 'ز', 'masafa': ' ', 'mash': ''  # 'mash' represents delete
}

# %%
# Create a dynamic label map based on the encoder's order
label_map = {i: english_to_arabic[label] for i, label in enumerate(label_encoder.classes_)}
print(f"Label Map: {label_map}")  # Ensure it matches your expectations
# Out:
# Label Map: {0: 'ع', 1: 'ال', 2: 'ا', 3: 'ب', 4: 'ض', 5: 'د', 6: 'ف', 7: 'غ', 8: 'ح', 9: 'ه', 10: 'ج', 11: 'ك', 12: 'خ', 13: 'لا', 14: 'ل', 15: 'م', 16: 'ن', 17: 'ق', 18: 'ر', 19: 'ص', 20: 'س', 21: 'ش', 22: 'ط', 23: 'ت', 24: 'ة', 25: 'ذ', 26: 'ث', 27: 'و', 28: 'ي', 29: 'ظ', 30: 'ز', 31: ' ', 32: ''}

# %%
# Normalize images Converts pixel values from [0, 255] to [0, 1] to improve model performance.
X = X / 255.0

# %%
# Split dataset into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

# %%
def create_cnn_model():
    model = Sequential()

    # 1st Convolutional Block
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # 2nd Convolutional Block
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # 3rd Convolutional Block
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # New 4th Convolutional Block
    model.add(Conv2D(256, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    #Convolution + MaxPooling layers: Extract spatial features and reduce the size of the feature map
    # Flattening Converts the 2D output of the final MaxPooling layer into a 1D vector
    model.add(Flatten())

    # Fully Connected Layers
    model.add(Dense(256, activation='relu'))  # New Fully Connected Layer
    model.add(Dropout(0.5))  # Dropout to prevent overfitting

    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))  # Additional dropout layer for robustness

    # Output Layer
    model.add(Dense(len(label_encoder.classes_), activation='softmax'))

    return model

# %%
# Create the enhanced model
model = create_cnn_model()
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 62, 62, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 29, 29, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 33)             │         4,257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 687,969 (2.62 MB)
#  Trainable params: 687,969 (2.62 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# %%
# Train the model
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=32),
    validation_data=(X_val, y_val),
    epochs=100
)
# Save the model
model.save('asl_cnn2_model.h5')
# Out:
# Epoch 1/100
# c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 11s 44ms/step - accuracy: 0.0310 - loss: 3.5001 - val_accuracy: 0.0369 - val_loss: 3.4941
# Epoch 2/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.0401 - loss: 3.4854 - val_accuracy: 0.0393 - val_loss: 3.4004
# Epoch 3/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - accuracy: 0.0560 - loss: 3.4031 - val_accuracy: 0.0811 - val_loss: 3.2198
# Epoch 4/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - accuracy: 0.1032 - loss: 3.1761 - val_accuracy: 0.1852 - val_loss: 2.8043
# Epoch 5/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 17s 81ms/step - accuracy: 0.1548 - loss: 2.8976 - val_accuracy: 0.2149 - val_loss: 2.6098
# Epoch 6/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.1993 - loss: 2.6691 - val_accuracy: 0.2875 - val_loss: 2.2776
# Epoch 7/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 21s 101ms/step - accuracy: 0.2673 - loss: 2.4226 - val_accuracy: 0.3402 - val_loss: 2.0939
# Epoch 8/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.2925 - loss: 2.2117 - val_accuracy: 0.4025 - val_loss: 1.8540
# Epoch 9/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 16s 75ms/step - accuracy: 0.3454 - loss: 2.0557 - val_accuracy: 0.4413 - val_loss: 1.7134
# Epoch 10/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 16s 76ms/step - accuracy: 0.3877 - loss: 1.9108 - val_accuracy: 0.4806 - val_loss: 1.5826
# Epoch 11/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 16s 77ms/step - accuracy: 0.4135 - loss: 1.8189 - val_accuracy: 0.5024 - val_loss: 1.5364
# Epoch 12/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - accuracy: 0.4385 - loss: 1.7019 - val_accuracy: 0.5412 - val_loss: 1.4330
# Epoch 13/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - accuracy: 0.4661 - loss: 1.6099 - val_accuracy: 0.5962 - val_loss: 1.2917
# Epoch 14/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 13s 61ms/step - accuracy: 0.4955 - loss: 1.5347 - val_accuracy: 0.6071 - val_loss: 1.2157
# Epoch 15/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step - accuracy: 0.5235 - loss: 1.4509 - val_accuracy: 0.6041 - val_loss: 1.2721
# Epoch 16/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - accuracy: 0.5367 - loss: 1.4317 - val_accuracy: 0.6507 - val_loss: 1.1293
# Epoch 17/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 12s 58ms/step - accuracy: 0.5724 - loss: 1.3471 - val_accuracy: 0.6544 - val_loss: 1.0457
# Epoch 18/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.5575 - loss: 1.3162 - val_accuracy: 0.6380 - val_loss: 1.1167
# Epoch 19/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 16s 76ms/step - accuracy: 0.5909 - loss: 1.2516 - val_accuracy: 0.6792 - val_loss: 0.9764
# Epoch 20/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.5927 - loss: 1.2456 - val_accuracy: 0.6749 - val_loss: 0.9584
# Epoch 21/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 16s 76ms/step - accuracy: 0.6214 - loss: 1.1736 - val_accuracy: 0.6768 - val_loss: 0.9892
# Epoch 22/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 15s 74ms/step - accuracy: 0.6221 - loss: 1.1383 - val_accuracy: 0.6943 - val_loss: 0.9626
# Epoch 23/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - accuracy: 0.6311 - loss: 1.1125 - val_accuracy: 0.6901 - val_loss: 0.9344
# Epoch 24/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.6449 - loss: 1.0568 - val_accuracy: 0.6937 - val_loss: 0.9491
# Epoch 25/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 16s 77ms/step - accuracy: 0.6650 - loss: 1.0302 - val_accuracy: 0.6979 - val_loss: 0.8696
# Epoch 26/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 13s 61ms/step - accuracy: 0.6490 - loss: 1.0819 - val_accuracy: 0.7046 - val_loss: 0.8729
# Epoch 27/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 16s 75ms/step - accuracy: 0.6646 - loss: 0.9910 - val_accuracy: 0.7173 - val_loss: 0.8449
# Epoch 28/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 16s 76ms/step - accuracy: 0.6824 - loss: 0.9849 - val_accuracy: 0.7421 - val_loss: 0.8104
# Epoch 29/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 15s 74ms/step - accuracy: 0.6710 - loss: 0.9721 - val_accuracy: 0.7234 - val_loss: 0.8259
# Epoch 30/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.7003 - loss: 0.9263 - val_accuracy: 0.7397 - val_loss: 0.8052
# Epoch 31/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 16s 75ms/step - accuracy: 0.6927 - loss: 0.9507 - val_accuracy: 0.7343 - val_loss: 0.7623
# Epoch 32/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 15s 71ms/step - accuracy: 0.7017 - loss: 0.8992 - val_accuracy: 0.7488 - val_loss: 0.7295
# Epoch 33/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.7018 - loss: 0.8977 - val_accuracy: 0.7585 - val_loss: 0.7355
# Epoch 34/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 13s 63ms/step - accuracy: 0.7222 - loss: 0.8552 - val_accuracy: 0.7615 - val_loss: 0.7058
# Epoch 35/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 12s 59ms/step - accuracy: 0.7257 - loss: 0.8138 - val_accuracy: 0.7409 - val_loss: 0.7755
# Epoch 36/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.7265 - loss: 0.8603 - val_accuracy: 0.7712 - val_loss: 0.7463
# Epoch 37/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7234 - loss: 0.8095 - val_accuracy: 0.7397 - val_loss: 0.7938
# Epoch 38/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.7342 - loss: 0.8232 - val_accuracy: 0.7482 - val_loss: 0.7762
# Epoch 39/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.7504 - loss: 0.7722 - val_accuracy: 0.7724 - val_loss: 0.6953
# Epoch 40/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7487 - loss: 0.7916 - val_accuracy: 0.7639 - val_loss: 0.7434
# Epoch 41/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.7397 - loss: 0.7953 - val_accuracy: 0.7627 - val_loss: 0.7495
# Epoch 42/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.7473 - loss: 0.7453 - val_accuracy: 0.7639 - val_loss: 0.7214
# Epoch 43/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7496 - loss: 0.7529 - val_accuracy: 0.7682 - val_loss: 0.7382
# Epoch 44/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.7477 - loss: 0.7536 - val_accuracy: 0.7645 - val_loss: 0.7111
# Epoch 45/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7595 - loss: 0.7207 - val_accuracy: 0.7930 - val_loss: 0.6492
# Epoch 46/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7552 - loss: 0.7265 - val_accuracy: 0.7954 - val_loss: 0.6686
# Epoch 47/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.7705 - loss: 0.6914 - val_accuracy: 0.7948 - val_loss: 0.6572
# Epoch 48/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7657 - loss: 0.7057 - val_accuracy: 0.8008 - val_loss: 0.6631
# Epoch 49/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7701 - loss: 0.6896 - val_accuracy: 0.7924 - val_loss: 0.6844
# Epoch 50/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.7765 - loss: 0.7086 - val_accuracy: 0.7875 - val_loss: 0.6629
# Epoch 51/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.7790 - loss: 0.6995 - val_accuracy: 0.7851 - val_loss: 0.6876
# Epoch 52/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7725 - loss: 0.6900 - val_accuracy: 0.7954 - val_loss: 0.6412
# Epoch 53/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7809 - loss: 0.6952 - val_accuracy: 0.7869 - val_loss: 0.6786
# Epoch 54/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.7718 - loss: 0.7033 - val_accuracy: 0.8051 - val_loss: 0.6377
# Epoch 55/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.7853 - loss: 0.6641 - val_accuracy: 0.8075 - val_loss: 0.6384
# Epoch 56/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.7990 - loss: 0.6052 - val_accuracy: 0.7942 - val_loss: 0.6590
# Epoch 57/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.7837 - loss: 0.6877 - val_accuracy: 0.7881 - val_loss: 0.6744
# Epoch 58/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7997 - loss: 0.6298 - val_accuracy: 0.7942 - val_loss: 0.6853
# Epoch 59/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.7932 - loss: 0.6606 - val_accuracy: 0.8027 - val_loss: 0.6505
# Epoch 60/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.7939 - loss: 0.6265 - val_accuracy: 0.7996 - val_loss: 0.6638
# Epoch 61/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8008 - loss: 0.6454 - val_accuracy: 0.7954 - val_loss: 0.6624
# Epoch 62/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.7830 - loss: 0.6592 - val_accuracy: 0.8172 - val_loss: 0.5941
# Epoch 63/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.7976 - loss: 0.5996 - val_accuracy: 0.7978 - val_loss: 0.6555
# Epoch 64/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7928 - loss: 0.6339 - val_accuracy: 0.8238 - val_loss: 0.6323
# Epoch 65/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.7961 - loss: 0.6176 - val_accuracy: 0.8202 - val_loss: 0.6133
# Epoch 66/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.8102 - loss: 0.5795 - val_accuracy: 0.8136 - val_loss: 0.6212
# Epoch 67/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - accuracy: 0.8087 - loss: 0.5822 - val_accuracy: 0.8226 - val_loss: 0.6446
# Epoch 68/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - accuracy: 0.8014 - loss: 0.5951 - val_accuracy: 0.8027 - val_loss: 0.6484
# Epoch 69/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 13s 62ms/step - accuracy: 0.8100 - loss: 0.6054 - val_accuracy: 0.8142 - val_loss: 0.6161
# Epoch 70/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.8146 - loss: 0.5610 - val_accuracy: 0.8208 - val_loss: 0.6155
# Epoch 71/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.8172 - loss: 0.5707 - val_accuracy: 0.8063 - val_loss: 0.6554
# Epoch 72/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.8137 - loss: 0.5866 - val_accuracy: 0.8184 - val_loss: 0.5947
# Epoch 73/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.8138 - loss: 0.5678 - val_accuracy: 0.8202 - val_loss: 0.6011
# Epoch 74/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.8219 - loss: 0.5399 - val_accuracy: 0.8287 - val_loss: 0.5770
# Epoch 75/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.8245 - loss: 0.5544 - val_accuracy: 0.8184 - val_loss: 0.6265
# Epoch 76/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.8301 - loss: 0.5457 - val_accuracy: 0.8172 - val_loss: 0.6357
# Epoch 77/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.8339 - loss: 0.5445 - val_accuracy: 0.8002 - val_loss: 0.6620
# Epoch 78/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.8208 - loss: 0.5354 - val_accuracy: 0.8184 - val_loss: 0.6211
# Epoch 79/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.8360 - loss: 0.5155 - val_accuracy: 0.8281 - val_loss: 0.5747
# Epoch 80/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.8182 - loss: 0.5943 - val_accuracy: 0.8154 - val_loss: 0.6003
# Epoch 81/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.8167 - loss: 0.5651 - val_accuracy: 0.8360 - val_loss: 0.5475
# Epoch 82/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.8285 - loss: 0.5436 - val_accuracy: 0.8069 - val_loss: 0.6313
# Epoch 83/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.8309 - loss: 0.5155 - val_accuracy: 0.8172 - val_loss: 0.6164
# Epoch 84/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.8334 - loss: 0.5163 - val_accuracy: 0.8493 - val_loss: 0.5539
# Epoch 85/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.8224 - loss: 0.5510 - val_accuracy: 0.8281 - val_loss: 0.5761
# Epoch 86/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.8374 - loss: 0.4871 - val_accuracy: 0.8378 - val_loss: 0.5248
# Epoch 87/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.8266 - loss: 0.5278 - val_accuracy: 0.8366 - val_loss: 0.5552
# Epoch 88/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.8349 - loss: 0.5116 - val_accuracy: 0.8299 - val_loss: 0.5824
# Epoch 89/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.8424 - loss: 0.5040 - val_accuracy: 0.8208 - val_loss: 0.6049
# Epoch 90/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.8407 - loss: 0.4832 - val_accuracy: 0.8148 - val_loss: 0.5949
# Epoch 91/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.8425 - loss: 0.4856 - val_accuracy: 0.8366 - val_loss: 0.5544
# Epoch 92/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.8445 - loss: 0.4864 - val_accuracy: 0.8390 - val_loss: 0.5547
# Epoch 93/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.8562 - loss: 0.4432 - val_accuracy: 0.8081 - val_loss: 0.6703
# Epoch 94/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.8405 - loss: 0.5065 - val_accuracy: 0.8450 - val_loss: 0.5400
# Epoch 95/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8587 - loss: 0.4416 - val_accuracy: 0.7996 - val_loss: 0.6923
# Epoch 96/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.8324 - loss: 0.5391 - val_accuracy: 0.8281 - val_loss: 0.5963
# Epoch 97/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.8463 - loss: 0.4745 - val_accuracy: 0.8378 - val_loss: 0.5419
# Epoch 98/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.8554 - loss: 0.4496 - val_accuracy: 0.8360 - val_loss: 0.5239
# Epoch 99/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8594 - loss: 0.4518 - val_accuracy: 0.8305 - val_loss: 0.5717
# Epoch 100/100
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.8506 - loss: 0.4741 - val_accuracy: 0.8299 - val_loss: 0.6160
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Evaluate the model on the validation set
val_loss, val_acc = model.evaluate(X_val, y_val, verbose=2)
print(f'Validation Accuracy: {val_acc * 100:.2f}%')
# Out:
# 52/52 - 1s - 12ms/step - accuracy: 0.8299 - loss: 0.6160
# Validation Accuracy: 82.99%

# %% [markdown]
# # Load Saved model for evaluations

# %%
# Load label encoder and define label map dynamically
label_encoder = LabelEncoder()
label_encoder.classes_ = np.load('label_classes.npy', allow_pickle=True)  # Ensure to save and load classes
label_map = {i: english_to_arabic[label] for i, label in enumerate(label_encoder.classes_)}

# %%
# (Re)load your evaluation/test dataset – here we assume the same loading function as before.
def load_dataset(folder):
    images = []
    labels = []
    for label in os.listdir(folder):
        label_folder = os.path.join(folder, label)
        if os.path.isdir(label_folder):
            for img_file in os.listdir(label_folder):
                img_path = os.path.join(label_folder, img_file)
                img = cv2.imread(img_path)
                if img is not None:
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    img = cv2.resize(img, (224, 224))
                    images.append(img)
                    labels.append(label)
    return np.array(images), np.array(labels)

# %%
# Specify the test or evaluation dataset path (it could be a dedicated folder)
test_dataset_path = 'RGB ArSL dataset'  # adjust as needed
X_test, y_test = load_dataset(test_dataset_path)

# %%
# Preprocess the test images
X_test = preprocess_input(X_test)
y_test_encoded = label_encoder.transform(y_test)
y_test_cat = tf.keras.utils.to_categorical(y_test_encoded, num_classes=len(label_encoder.classes_))

# %%
# Load the saved model
model = load_model('asl_cnn2_model.h5')

# %%
# Evaluate on the test set
test_loss, test_acc = model.evaluate(X_test, y_test_cat, verbose=2)
print(f'Test Accuracy: {test_acc * 100:.2f}%')

# %%
# Get predictions for evaluation metrics
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test_cat, axis=1)

# %%
# Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=label_encoder.classes_))

# %%
# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Load saved model for real time

# %%
# Load the saved model for real-time inference
model = load_model('asl_cnn2_model.h5')

# %%
# Load label encoder and define label map dynamically
label_encoder = LabelEncoder()
label_encoder.classes_ = np.load('label_classes.npy', allow_pickle=True)  # Ensure to save and load classes
label_map = {i: english_to_arabic[label] for i, label in enumerate(label_encoder.classes_)}

# %%
# Initialize webcam
cap = cv2.VideoCapture(0)
captured_letters = []  # Store the formed sentence
last_predicted_label = None  # Track the previous prediction
frames_with_same_letter = 5  # Counter for consistent frames
cooldown_threshold = 20  # Threshold for consecutive frames with the same prediction
last_activity_time = time.time()  # Track time for inactivity
idle_timeout = 15  # Inactivity time limit (seconds)

def format_arabic_text(letters):
    """Format Arabic text to display properly from right to left."""
    return arabic_reshaper.reshape(''.join(letters))

def draw_text(frame, text, position):
    """Draw text on the video frame."""
    font = ImageFont.truetype("arial.ttf", 35)
    img_pil = Image.fromarray(frame)
    draw = ImageDraw.Draw(img_pil)
    draw.text(position, text, font=font, fill=(0, 255, 0))
    return np.array(img_pil)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Define Region of Interest (ROI)
    roi = frame[100:400, 100:400]
    cv2.rectangle(frame, (100, 100), (400, 400), (0, 255, 0), 2)

    # Predict the letter/gesture
    roi_resized = cv2.resize(roi, (64, 64)) / 255.0
    roi_resized = np.expand_dims(roi_resized, axis=0)
    prediction = model.predict(roi_resized, verbose=0)
    predicted_id = np.argmax(prediction)
    predicted_label = label_map.get(predicted_id, '')

    # Confidence filtering to avoid random predictions
    if np.max(prediction) < 0.7:
        predicted_label = None
    else:
        predicted_id = np.argmax(prediction)
        predicted_label = label_map.get(predicted_id, '')

    # Check if the prediction is consistent
    if predicted_label == last_predicted_label:
        frames_with_same_letter += 1
    else:
        frames_with_same_letter = 0  # Reset if prediction changes

    # Register the letter only if it remains consistent for the threshold
    if frames_with_same_letter >= cooldown_threshold:
        if predicted_label == 'masafa':
            captured_letters.append(' ')  # Arabic for space
        elif predicted_label == 'mash' and captured_letters:
            captured_letters.pop()  # Remove last letter for delete
        elif predicted_label and predicted_label not in ['masafa', 'mash']:
            captured_letters.append(predicted_label)

        # Reset tracking variables after registering the letter
        last_predicted_label = None
        frames_with_same_letter = 0
        last_activity_time = time.time()  # Reset the idle time

    else:
        last_predicted_label = predicted_label  # Update the last prediction
    
    # **Update last_activity_time if no valid sign is detected**
    if predicted_label is None or np.max(prediction) < 0.7:
        last_activity_time = time.time()  # Update on inactivity

    # Check for inactivity timeout
    if time.time() - last_activity_time > idle_timeout:
        print(f"Final Sentence: {format_arabic_text(captured_letters)}")
        break  # Exit the loop if idle for too long

    # Format and display the text on the frame
    sentence = format_arabic_text(captured_letters)
    frame = draw_text(frame, sentence, (10, 30))

    # Show the frame
    cv2.imshow('ASL Recognition', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        print(f"Final Sentence: {format_arabic_text(captured_letters)}")
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Final Sentence: ﺑﺎﺏ

# %% [markdown]
# ## 4 Convolutional Layers:
#
# # 1st Conv Layer: 32 filters, 3x3 kernel.
# # 2nd Conv Layer: 64 filters, 3x3 kernel.
# # 3rd Conv Layer: 128 filters, 3x3 kernel.
# # 4th Conv Layer: 256 filters, 3x3 kernel.
#
# # 4 MaxPooling Layers:
#
# # After each convolutional layer, MaxPooling reduces the feature map size.
#
# # 1 Flatten Layer:
# # Converts the 2D output of the final MaxPooling layer into a 1D vector.
#
# # 2 Dense (Fully Connected) Layers:
#
# # First Dense Layer: 256 neurons with ReLU activation.
# # Second Dense Layer: 128 neurons with ReLU activation.
#
# # 1 Dropout Layer after each Dense layer:
#
# # Prevents overfitting by randomly disabling neurons during training.
#
# # 1 Output Layer:
#
# # Uses softmax activation to output class probabilities.
